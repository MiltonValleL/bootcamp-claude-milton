# %% [markdown]
# ---
#
# # NUMERICAL SERIES AGGREGATION
#
# ---

# %% [markdown]
# >You can use this methods to **aggregate numerical Series**
#
# <br>
#
# >|**METHOD**|**DESCRIPTION**|
# >|:---|:---|
# >|**.count()**|Returns the number of items|
# >|**.first(), .last()**|Returns the first or last item|
# >|**.mean(), median()**|Calculates the `Mean` or `Median`|
# >|**.min(), .max()**|Returns the smallest and largest value|
# >|**.argmax(), .argmin())**|Returns the index for the smallest or largest values|
# >|**.std(), .var()**|Calculates the `Standard Deviation` or `Variance`|
# >|**.mad()**|Calculates the `Mean Absolute Deviation`|
# >|**.prod()**|Calculates the product of all the items|
# >|**.sum()**|Calculates the sum of all the items|
# >|**.quantile()**|Returns a specific `percentile`, or `list of percentiles`|
#
# <br>

# %%
import numpy as np
import pandas as pd

# %%
sales_series = pd.Series(
    data=[0, 5, 155, np.nan, 518], index=["coffee", "coffee", "tea", "coconut", "sugar"]
)
sales_series
# Out:
# coffee       0.0
# coffee       5.0
# tea        155.0
# coconut      NaN
# sugar      518.0
# dtype: float64
